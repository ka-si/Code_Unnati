# %%
print("Hello world!")
# Out:
# Hello world!

# %% [markdown]
# # Sigmoid

# %% [markdown]
# ![image.png](attachment:image.png)#

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #  Machine Learning Logistic Regression on  Dataset
